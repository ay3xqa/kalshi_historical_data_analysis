# %%
import pandas as pd

def calculate_total_payout_naive(df):
    # Initialize variables
    total_payout = 0
    num_hit = 0
    num_miss = 0

    # Prepare a list to collect rows for results
    filtered_rows = []

    # Iterate over rows
    for _, row in df.iterrows():
        if (
            row["outcome"] == row["contract_type"]
            and row["pdf_estimate"] >= row["current_kalshi_price"] + 10
            and row["current_kalshi_price"] >= 50
        ):
            total_payout += 100 / row["current_kalshi_price"] - 1
            num_hit += 1
            filtered_rows.append(row)  # Collect the row
        elif (
            row["outcome"] != row["contract_type"]
            and row["pdf_estimate"] >= row["current_kalshi_price"] + 10
            and row["current_kalshi_price"] >= 50
        ):
            total_payout -= 1
            num_miss += 1
            filtered_rows.append(row)  # Collect the row

    # Convert the collected rows into a DataFrame
    res = pd.DataFrame(filtered_rows)

    # Print the total payout
    print(f"Net Profit: {total_payout}")
    print(f"Total Trades: {num_hit}/{num_hit + num_miss}")

    # Return results for further processing
    return total_payout, num_hit, num_hit + num_miss, res

# %%
df = pd.read_csv("kalshi-historical-3-30-25-with-y.csv")
df['time'] = pd.to_datetime(df['time'])
df =  df[df['time'] > pd.Timestamp('2025-03-23')] 
df
# Out:
#                       time currency event_type contract_type  strike_price  \
# 77320  2025-03-24 11:27:28      BTC      Daily            No         89250
# 77321  2025-03-24 11:27:28      BTC      Daily           Yes         89250
# 77322  2025-03-24 11:27:28      BTC      Daily            No         88750
# 77323  2025-03-24 11:27:28      BTC      Daily           Yes         88750
# 77324  2025-03-24 11:27:28      BTC      Daily            No         88250
# ...                    ...      ...        ...           ...           ...
# 117127 2025-03-30 15:30:08      BTC      Daily           Yes         83250
# 117128 2025-03-30 15:30:08      BTC      Daily            No         82750
# 117129 2025-03-30 15:30:08      BTC      Daily           Yes         82750
# 117130 2025-03-30 15:30:08      BTC      Daily            No         82250
# 117131 2025-03-30 15:30:08      BTC      Daily           Yes         82250
#
#         pdf_estimate  current_kalshi_price outcome
# 77320          70.92                    90      No
# 77321          29.08                    16      No
# 77322          58.15                    79      No
# 77323          41.85                    28      No
# 77324          45.98                    62      No
# ...              ...                   ...     ...
# 117127         46.47                    18      No
# 117128         41.18                    66      No
# 117129         58.82                    42      No
# 117130         29.93                    34     Yes
# 117131         70.07                    75     Yes
#
# [39812 rows x 8 columns]

# %%
_, _, _, res_df = calculate_total_payout_naive(df)
res_df
# Out:
# Net Profit: 792.5048570216084
# Total Trades: 3852/4608
#                       time currency event_type contract_type  strike_price  \
# 77825  2025-03-24 13:18:04      BTC      Daily           Yes         88250
# 77833  2025-03-24 13:20:05      BTC      Daily           Yes         88250
# 77925  2025-03-24 13:44:05      BTC      Daily           Yes         88250
# 77931  2025-03-24 13:46:05      BTC      Daily           Yes         88250
# 78061  2025-03-24 14:24:05      BTC      Daily           Yes         88250
# ...                    ...      ...        ...           ...           ...
# 116559 2025-03-30 13:02:04      BTC      Daily           Yes         82250
# 116569 2025-03-30 13:04:04      BTC      Daily           Yes         82250
# 116619 2025-03-30 13:14:05      BTC      Daily           Yes         82250
# 116757 2025-03-30 13:46:04      BTC      Daily           Yes         82250
# 116929 2025-03-30 14:28:07      BTC      Daily           Yes         82750
#
#         pdf_estimate  current_kalshi_price outcome
# 77825          61.31                    50      No
# 77833          61.00                    51      No
# 77925          64.77                    54      No
# 77931          62.42                    50      No
# 78061          64.16                    51      No
# ...              ...                   ...     ...
# 116559         65.77                    53     Yes
# 116569         65.37                    53     Yes
# 116619         66.44                    56     Yes
# 116757         67.01                    55     Yes
# 116929         60.21                    50      No
#
# [4608 rows x 8 columns]

# %%
# 
def calculate_total_payout_three_daily_limit_with_no_same_position(df):
    # Initialize variables
    total_payout = 0
    num_hit = 0
    num_miss = 0

    # Prepare a list to collect rows for results
    filtered_rows = []

    # Track active trades per day
    trades_per_day = {}

    # Iterate over rows
    for _, row in df.iterrows():
        # Extract date from time (assuming 'time' is in datetime format)
        trade_day = row["time"].date()
        contract_key = (row["contract_type"], row["strike_price"])

        # Check if we already have 3 active trades for this day
        if contract_key not in trades_per_day.get(trade_day, []):
            # Entry condition: Model prediction >= current kalshi price + 10 and kalshi price >= 50
            if (
                row["pdf_estimate"] >= row["current_kalshi_price"] + 10
                and row["current_kalshi_price"] >= 50
            ):
                # Register the trade for that day
                if trade_day not in trades_per_day:
                    trades_per_day[trade_day] = []
                if len(trades_per_day[trade_day]) < 3:  # Only allow 3 trades per day
                    trades_per_day[trade_day].append(contract_key)
                    
                    # Calculate payout based on outcome
                    if row["outcome"] == row["contract_type"]:
                        total_payout += 100 / row["current_kalshi_price"] - 1  # Winning payout
                        num_hit += 1
                    elif row["outcome"] != row["contract_type"]:
                        total_payout -= 1  # Losing payout
                        num_miss += 1

                    # Collect the row for results
                    filtered_rows.append(row)  # Add this trade row

    # Convert the collected rows into a DataFrame for results
    res = pd.DataFrame(filtered_rows)

    # Print the total payout and results summary
    print(f"Net Profit: {total_payout}")
    print(f"Total Trades: {num_hit}/{num_hit + num_miss}")
    print(f"Winning Trades: {num_hit}")
    print(f"Losing Trades: {num_miss}")

    # Return results for further processing
    return total_payout, num_hit, num_hit + num_miss, res

# %%
_, _, _, res_df = calculate_total_payout_three_daily_limit_with_no_same_position(df)
res_df
# Out:
# Net Profit: -9.94210205796424
# Total Trades: 24/53
# Winning Trades: 24
# Losing Trades: 29
#                      time currency event_type contract_type  strike_price  \
# 271   2025-01-16 09:44:00      BTC      Daily           Yes         98250
# 273   2025-01-16 09:44:00      BTC      Daily           Yes         97750
# 291   2025-01-16 09:46:00      BTC      Daily           Yes         97250
# 3625  2025-01-20 13:20:00      BTC      Daily           Yes        103750
# 7063  2025-01-21 11:10:00      BTC      Daily            No        105000
# 7085  2025-01-21 11:12:00      BTC      Daily            No        106000
# 9742  2025-01-23 09:34:00      BTC      Daily            No        103750
# 10179 2025-01-23 10:10:00      BTC      Daily           Yes        103250
# 10181 2025-01-23 10:10:00      BTC      Daily           Yes        102750
# 13470 2025-01-24 14:46:00      BTC      Daily           Yes        105750
# 14131 2025-01-27 09:50:00      BTC      Daily            No        102000
# 10181         78.73                    61     Yes
# 13470         66.51                    52      No
# 14131         60.29                    50      No
# 17424         64.01                    53      No
# 18246         69.13                    59      No
# 19616         77.67                    65      No
# 20044         62.18                    51     Yes
# 22445         68.76                    57     Yes
# 23042         67.89                    56     Yes
# 23760         68.24                    56      No
# 25652         70.30                    60     Yes
# 27506         78.77                    68     Yes
# 27773         87.14                    76     Yes
# 27775         87.14                    69     Yes
# 27777         84.58                    60     Yes
# 32650         69.45                    52     Yes
# 32652         75.10                    63     Yes
# 32688         79.63                    67     Yes
# 40544         66.30                    56      No
# 40922         74.41                    62      No
# 43840         64.24                    51     Yes
# 44225        126.33                    86     Yes
# 45027         70.20                    58     Yes
# 45902         67.29                    56      No
# 45982         83.22                    57      No
# 46384         62.32                    50     Yes
# 46676         62.51                    50     Yes
# 47010         63.63                    50      No
# 48510         61.69                    50      No
# 49070         72.51                    62      No
# 50322         61.22                    51      No
# 50366         63.05                    50      No
# 51580         82.06                    69     Yes
# 51752         64.21                    50     Yes
# 51754         69.03                    59     Yes
# 62642         60.94                    50      No
# 63166         63.73                    51     Yes
# 63954         72.86                    52     Yes
# 64532         61.69                    50     Yes
# 64534         72.34                    58     Yes
# 67361         66.75                    55      No
# 68599         69.19                    56      No
# 69919         62.56                    50     Yes
# 71523         63.66                    50      No
# 71629         70.50                    53      No

# %%
def calculate_total_payout_three_daily_limit_with_limit_sells(df):
    # Initialize variables
    total_payout = 0
    num_hit = 0
    num_miss = 0

    # Prepare a list to collect rows for results
    filtered_rows = []

    # Track active trades per day
    trades_per_day = {}

    # Store active trades with their limit order prices
    active_trades = {}

    # Iterate over rows
    for _, row in df.iterrows():
        # Extract date from time (assuming 'time' is in datetime format)
        trade_day = row["time"].date()
        contract_key = (row["contract_type"], row["strike_price"])

        # Check if we already have 3 active trades for this day
        if contract_key not in trades_per_day.get(trade_day, []):
            # Entry condition: Model prediction >= current kalshi price + 10 and kalshi price >= 50
            if (
                row["pdf_estimate"] >= row["current_kalshi_price"] + 10
                and row["current_kalshi_price"] >= 50
            ):
                # Register the trade for that day
                if trade_day not in trades_per_day:
                    trades_per_day[trade_day] = []
                if len(trades_per_day[trade_day]) < 3:  # Only allow 3 trades per day
                    trades_per_day[trade_day].append(contract_key)

                    # Set a limit order to exit at pdf_estimate - 5
                    limit_price = row["pdf_estimate"] - 5

                    # Record the trade in active_trades
                    active_trades[contract_key] = {
                        "entry_time": row["time"],
                        "entry_price": row["current_kalshi_price"],
                        "limit_price": limit_price,
                        "entered": True,
                        "exit_time": None,
                        "exit_price": None,
                        "outcome": None,
                    }

                    # Collect the row for results
                    filtered_rows.append(row)

        # Check for limit order exit condition in active trades
        if contract_key in active_trades and active_trades[contract_key]["entered"]:
            # If the price exceeds the limit, exit the trade
            if row["current_kalshi_price"] >= active_trades[contract_key]["limit_price"]:
                # Record the exit details
                active_trades[contract_key]["exit_time"] = row["time"]
                active_trades[contract_key]["exit_price"] = row["current_kalshi_price"]

                # Calculate gain or loss
                if row["outcome"] == row["contract_type"]:
                    total_payout += 100 / row["current_kalshi_price"] - 1  # Winning payout
                    num_hit += 1
                elif row["outcome"] != row["contract_type"]:
                    total_payout -= 1  # Losing payout
                    num_miss += 1

                # Mark the trade as exited
                active_trades[contract_key]["entered"] = False

                # Add the row to the filtered results
                filtered_rows.append(row)

    # Convert the collected rows into a DataFrame for results
    res = pd.DataFrame(filtered_rows)

    # Print the total payout and results summary
    print(f"Net Profit: {total_payout}")
    print(f"Total Trades: {num_hit}/{num_hit + num_miss}")
    print(f"Winning Trades: {num_hit}")
    print(f"Losing Trades: {num_miss}")

    # Return results for further processing
    return total_payout, num_hit, num_hit + num_miss, res

# %%
df = pd.read_csv("kalshi-historical-3-16-25-with-y.csv")
df['time'] = pd.to_datetime(df['time'])

_, _, _, res_df = calculate_total_payout_three_daily_limit_with_limit_sells(df)
res_df
# Out:
# Net Profit: -5.567916636941719
# Total Trades: 28/46
# Winning Trades: 28
# Losing Trades: 18
#                      time currency event_type contract_type  strike_price  \
# 271   2025-01-16 09:44:00      BTC      Daily           Yes         98250
# 273   2025-01-16 09:44:00      BTC      Daily           Yes         97750
# 291   2025-01-16 09:46:00      BTC      Daily           Yes         97250
# 589   2025-01-16 10:22:00      BTC      Daily           Yes         97250
# 799   2025-01-16 10:52:00      BTC      Daily           Yes         98250
# ...                   ...      ...        ...           ...           ...
# 69119 2025-03-13 14:24:05      BTC      Daily           Yes         80500
# 69919 2025-03-14 10:00:04      BTC      Daily           Yes         83250
# 69967 2025-03-14 10:06:05      BTC      Daily           Yes         83250
# 71523 2025-03-14 15:24:05      BTC      Daily           Yes         84750
# 71629 2025-03-14 16:14:05      BTC      Daily           Yes         84250
#
#        pdf_estimate  current_kalshi_price outcome
# 271           65.01                    52     Yes
# 273           80.68                    64     Yes
# 291           78.65                    66     Yes
# 589           66.85                    75     Yes
# 799           56.21                    64     Yes
# ...             ...                   ...     ...
# 69119         66.44                    67      No
# 69919         62.56                    50     Yes
# 69967         54.47                    58     Yes
# 71523         63.66                    50      No
# 71629         70.50                    53      No
#
# [99 rows x 8 columns]

# %%
import pandas as pd

def calculate_total_payout_limits(df, unit_size=1):
    total_payout = 0
    num_hit = 0
    num_miss = 0

    filtered_rows = []

    # Track active trades for each day (max 3 trades per day)
    trades_per_day = {}

    # Store active trades (contract_key: (entry_time, entry_price))
    active_trades = {}

    # Iterate over the rows in the dataframe
    for idx, row in df.iterrows():
        # Get the current day (we only care about the date part)
        trade_day = row["time"].date()
        contract_key = (row["contract_type"], row["strike_price"], trade_day)
        
        # Ensure we have a maximum of 3 trades per day
        if trade_day not in trades_per_day:
            trades_per_day[trade_day] = []

        # Entry condition: If we haven't reached 3 trades for the day and the entry condition is met
        if True:
            if row["pdf_estimate"] >= row["current_kalshi_price"] + 10 and row["current_kalshi_price"] >= 50:
                # Register the trade for the day
                trades_per_day[trade_day].append(contract_key)

                # Store the trade entry details
                active_trades[contract_key] = {
                    "entry_time": row["time"],
                    "entry_price": row["current_kalshi_price"],
                    "limit_price": row["pdf_estimate"],
                    "exited": False,
                    "exit_time": None,
                    "exit_price": None,
                    "outcome": row["outcome"]
                }
                # Add this row to the filtered rows (this is the trade entry)
                filtered_rows.append(row)

        # Now we need to check if a limit sell opportunity exists for each active trade
        for trade_contract_key, trade in list(active_trades.items()):
            # Look ahead for a limit sell opportunity (price >= entry_price - 5)
            if not trade["exited"]:
                if trade_day == trade["entry_time"].date() and row["time"] > trade["entry_time"] and trade_contract_key == contract_key and row["current_kalshi_price"] >= trade["limit_price"]:
                    # Mark the trade as exited
                    trade["exit_time"] = row["time"]
                    trade["exit_price"] = trade["limit_price"]
                    trade["exited"] = True

                    # print(trade["entry_time"],trade["entry_price"], trade_contract_key)
                    # print(row["time"],row["current_kalshi_price"], contract_key)


                    # Calculate profit (gain or loss)
                    gain = (trade["exit_price"] / trade["entry_price"]) - 1
                    total_payout += gain * unit_size
                    num_hit += 1

    # Handle any remaining active trades at the end of the last day in the dataset
    for trade_contract_key, trade in list(active_trades.items()):
        if not trade["exited"]:
            if trade_contract_key[0] != trade["outcome"]:
                total_payout -= 1  # Apply -1 penalty for missed exit
                num_miss += 1
                trade["exited"] = True
                print(trade_contract_key, trade)
            else:
                total_payout += (trade["limit_price"] / trade["entry_price"]) - 1
                num_hit += 1
                trade["exited"] = True

    # Convert the filtered rows into a DataFrame for results
    res_df = pd.DataFrame(filtered_rows)

    # Print the final summary
    print(f"Net Profit in Units: {total_payout}")
    print(f"Total Trades: {num_hit}/{num_hit + num_miss}")
    print(f"Winning Trades: {num_hit}")
    print(f"Losing Trades: {num_miss}")

    return total_payout, num_hit, num_hit + num_miss, res_df

# %%
df = pd.read_csv("kalshi-historical-3-30-25-with-y.csv")
df['time'] = pd.to_datetime(df['time'])
_, _, _, res_df = calculate_total_payout_limits(df)
res_df
# Out:
# ('No', 105000, datetime.date(2025, 1, 21)) {'entry_time': Timestamp('2025-01-21 11:42:00'), 'entry_price': 52, 'limit_price': 62.39, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('Yes', 103750, datetime.date(2025, 1, 23)) {'entry_time': Timestamp('2025-01-23 15:52:00'), 'entry_price': 52, 'limit_price': 64.07, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 105750, datetime.date(2025, 1, 24)) {'entry_time': Timestamp('2025-01-24 14:46:00'), 'entry_price': 52, 'limit_price': 66.50999999999999, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 100750, datetime.date(2025, 1, 28)) {'entry_time': Timestamp('2025-01-28 16:46:00'), 'entry_price': 59, 'limit_price': 73.57, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 105500, datetime.date(2025, 1, 30)) {'entry_time': Timestamp('2025-01-30 15:36:00'), 'entry_price': 55, 'limit_price': 71.27, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('No', 97500, datetime.date(2025, 2, 3)) {'entry_time': Timestamp('2025-02-03 09:34:00'), 'entry_price': 76, 'limit_price': 87.14, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('No', 97000, datetime.date(2025, 2, 3)) {'entry_time': Timestamp('2025-02-03 09:34:00'), 'entry_price': 69, 'limit_price': 87.14, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('No', 96500, datetime.date(2025, 2, 3)) {'entry_time': Timestamp('2025-02-03 09:34:00'), 'entry_price': 60, 'limit_price': 84.58, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('No', 96000, datetime.date(2025, 2, 3)) {'entry_time': Timestamp('2025-02-03 09:34:00'), 'entry_price': 51, 'limit_price': 81.78, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('No', 99000, datetime.date(2025, 2, 3)) {'entry_time': Timestamp('2025-02-03 10:26:02'), 'entry_price': 60, 'limit_price': 73.75, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('Yes', 98250, datetime.date(2025, 2, 14)) {'entry_time': Timestamp('2025-02-14 11:42:01'), 'entry_price': 56, 'limit_price': 66.3, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('No', 94500, datetime.date(2025, 2, 18)) {'entry_time': Timestamp('2025-02-18 13:42:00'), 'entry_price': 86, 'limit_price': 126.33, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('No', 96000, datetime.date(2025, 2, 19)) {'entry_time': Timestamp('2025-02-19 12:16:00'), 'entry_price': 58, 'limit_price': 70.2, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'Yes'}
# ('Yes', 96000, datetime.date(2025, 2, 21)) {'entry_time': Timestamp('2025-02-21 12:38:00'), 'entry_price': 51, 'limit_price': 63.03, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 95500, datetime.date(2025, 2, 21)) {'entry_time': Timestamp('2025-02-21 12:44:00'), 'entry_price': 50, 'limit_price': 72.69, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 84750, datetime.date(2025, 2, 28)) {'entry_time': Timestamp('2025-02-28 13:56:05'), 'entry_price': 51, 'limit_price': 68.25, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 89750, datetime.date(2025, 3, 3)) {'entry_time': Timestamp('2025-03-03 13:06:05'), 'entry_price': 51, 'limit_price': 67.34, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 88750, datetime.date(2025, 3, 3)) {'entry_time': Timestamp('2025-03-03 13:24:06'), 'entry_price': 51, 'limit_price': 61.22, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 87750, datetime.date(2025, 3, 3)) {'entry_time': Timestamp('2025-03-03 13:30:05'), 'entry_price': 50, 'limit_price': 63.05, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 86750, datetime.date(2025, 3, 3)) {'entry_time': Timestamp('2025-03-03 14:46:05'), 'entry_price': 51, 'limit_price': 62.84, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 86250, datetime.date(2025, 3, 3)) {'entry_time': Timestamp('2025-03-03 16:44:05'), 'entry_price': 51, 'limit_price': 61.69, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 87750, datetime.date(2025, 3, 4)) {'entry_time': Timestamp('2025-03-04 16:48:05'), 'entry_price': 50, 'limit_price': 63.8, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 81500, datetime.date(2025, 3, 13)) {'entry_time': Timestamp('2025-03-13 11:34:06'), 'entry_price': 50, 'limit_price': 62.88, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 84750, datetime.date(2025, 3, 14)) {'entry_time': Timestamp('2025-03-14 15:24:05'), 'entry_price': 50, 'limit_price': 63.66, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 84250, datetime.date(2025, 3, 14)) {'entry_time': Timestamp('2025-03-14 16:44:05'), 'entry_price': 54, 'limit_price': 64.28, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 82750, datetime.date(2025, 3, 18)) {'entry_time': Timestamp('2025-03-18 22:08:04'), 'entry_price': 51, 'limit_price': 68.91, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 82250, datetime.date(2025, 3, 18)) {'entry_time': Timestamp('2025-03-18 22:08:04'), 'entry_price': 59, 'limit_price': 85.48, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 88000, datetime.date(2025, 3, 25)) {'entry_time': Timestamp('2025-03-25 17:36:07'), 'entry_price': 54, 'limit_price': 64.31, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 87250, datetime.date(2025, 3, 26)) {'entry_time': Timestamp('2025-03-26 23:58:04'), 'entry_price': 60, 'limit_price': 89.27, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 87750, datetime.date(2025, 3, 26)) {'entry_time': Timestamp('2025-03-26 22:52:04'), 'entry_price': 50, 'limit_price': 75.01, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 86750, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 00:30:07'), 'entry_price': 51, 'limit_price': 67.95, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 85750, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 02:58:04'), 'entry_price': 54, 'limit_price': 68.17, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 85250, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 09:46:04'), 'entry_price': 50, 'limit_price': 60.45, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 84250, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 11:52:05'), 'entry_price': 51, 'limit_price': 63.81, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:50:06'), 'entry_price': 65, 'limit_price': 76.89, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 83500, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 02:56:06'), 'entry_price': 66, 'limit_price': 76.33, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:58:05'), 'entry_price': 70, 'limit_price': 89.12, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 82750, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:58:05'), 'entry_price': 61, 'limit_price': 82.34, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:54:05'), 'entry_price': 53, 'limit_price': 78.46000000000001, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 82750, datetime.date(2025, 3, 30)) {'entry_time': Timestamp('2025-03-30 14:28:07'), 'entry_price': 50, 'limit_price': 60.21, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# ('Yes', 83250, datetime.date(2025, 3, 30)) {'entry_time': Timestamp('2025-03-30 00:56:05'), 'entry_price': 52, 'limit_price': 62.7, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No'}
# Net Profit in Units: 0.3005415879487072
# Total Trades: 198/239
# Winning Trades: 198
# Losing Trades: 41
#                       time currency event_type contract_type  strike_price  \
# 271    2025-01-16 09:44:00      BTC      Daily           Yes         98250
# 273    2025-01-16 09:44:00      BTC      Daily           Yes         97750
# 289    2025-01-16 09:46:00      BTC      Daily           Yes         97750
# 291    2025-01-16 09:46:00      BTC      Daily           Yes         97250
# 293    2025-01-16 09:46:00      BTC      Daily           Yes         96750
# ...                    ...      ...        ...           ...           ...
# 116559 2025-03-30 13:02:04      BTC      Daily           Yes         82250
# 116569 2025-03-30 13:04:04      BTC      Daily           Yes         82250
# 116619 2025-03-30 13:14:05      BTC      Daily           Yes         82250
# 116757 2025-03-30 13:46:04      BTC      Daily           Yes         82250
# 116929 2025-03-30 14:28:07      BTC      Daily           Yes         82750
#
#         pdf_estimate  current_kalshi_price outcome
# 271            65.01                    52     Yes
# 273            80.68                    64     Yes
# 289            78.65                    54     Yes
# 291            78.65                    66     Yes
# 293            89.21                    76     Yes
# ...              ...                   ...     ...
# 116559         65.77                    53     Yes
# 116569         65.37                    53     Yes
# 116619         66.44                    56     Yes
# 116757         67.01                    55     Yes
# 116929         60.21                    50      No
#
# [5237 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
from datetime import time
from collections import defaultdict


def calculate_total_payout_limits_and_price_history(df, unit_size=1):
    total_payout = 0
    num_hit = 0
    num_miss = 0

    filtered_rows = []

    # Track active trades for each day (max 3 trades per day)
    trades_per_day = {}

    # Store active trades (contract_key: (entry_time, entry_price))
    active_trades = defaultdict(list)

    price_history = {}
    stop_loss_cutoff = time(15, 30)  # "15:30" -> time(15, 30)


    # Iterate over the rows in the dataframe
    for idx, row in df.iterrows():
        # Get the current day (we only care about the date part)
        trade_day = row["time"].date()
        contract_key = (row["contract_type"], row["strike_price"], trade_day)
        # Initialize price history for the asset if not already tracked
        if contract_key not in price_history:
            price_history[contract_key] = []

        # Add current price to the price history for the asset
        price_history[contract_key].append(row["current_kalshi_price"])

        # Calculate the volatility based on the last 10 prices (adjust window size if needed)
        if len(price_history[contract_key]) > 10:
            volatility = np.std(price_history[contract_key][-10:])
        else:
            volatility = 0  # Not enough data for volatility calculation
            
        # Ensure we have a maximum of 3 trades per day
        if trade_day not in trades_per_day:
            trades_per_day[trade_day] = []

        # Entry condition: If we haven't reached 3 trades for the day and the entry condition is met
        if len(trades_per_day[trade_day]) < 99 and row["time"].time() <= stop_loss_cutoff:
            if row["pdf_estimate"] >= row["current_kalshi_price"] + 10 and row["current_kalshi_price"] >= 50:
                # Register the trade for the day
                trades_per_day[trade_day].append(contract_key)

                # Store the trade entry details
                active_trades[contract_key].append({
                    "entry_time": row["time"],
                    "entry_price": row["current_kalshi_price"],
                    "limit_price": row["pdf_estimate"],
                    "exited": False,
                    "exit_time": None,
                    "exit_price": None,
                    "outcome": row["outcome"],
                    "trailing_stop": row["current_kalshi_price"] - volatility * 3
                })
                # Add this row to the filtered rows (this is the trade entry)
                filtered_rows.append(row)

        # Now we need to check if a limit sell opportunity exists for each active trade
        for trade_contract_key, trades in list(active_trades.items()):
            for trade in trades:
                # Look ahead for a limit sell opportunity (price >= entry_price - 5)
                if not trade["exited"]:
                    if trade_day == trade["entry_time"].date() and row["time"] > trade["entry_time"] and trade_contract_key == contract_key:
                        if row["current_kalshi_price"] >= trade["limit_price"]:

                            # Mark the trade as exited
                            trade["exit_time"] = row["time"]
                            trade["exit_price"] = trade["limit_price"]
                            trade["exited"] = True

                            # print(trade["entry_time"],trade["entry_price"], trade_contract_key)
                            # print(row["time"],row["current_kalshi_price"], contract_key)

                            # Calculate profit (gain or loss)
                            gain = (trade["exit_price"] / trade["entry_price"]) - 1
                            total_payout += gain * unit_size
                            num_hit += 1
                        if row["current_kalshi_price"] <= trade["trailing_stop"] and row["time"].time() >= stop_loss_cutoff:
                            # Mark the trade as exited
                            trade["exit_time"] = row["time"]
                            trade["exit_price"] = row["current_kalshi_price"]
                            trade["exited"] = True

                            # print(trade["entry_time"],trade["entry_price"], trade_contract_key)
                            # print(row["time"],row["current_kalshi_price"], contract_key)

                            # Calculate profit (gain or loss)
                            gain = (trade["entry_price"] - row["current_kalshi_price"])/trade["entry_price"]
                            # print(trade_contract_key, trade)
                            total_payout -= gain * unit_size
                            num_miss += 1

    # Handle any remaining active trades at the end of the last day in the dataset
    for trade_contract_key, trades in list(active_trades.items()):
        for trade in trades:
            if not trade["exited"]:
                if trade_contract_key[0] != trade["outcome"]:
                    total_payout -= 1  # Apply -1 penalty for missed exit
                    num_miss += 1
                    trade["exited"] = True
                    print(trade_contract_key, trade)
                else:
                    total_payout += (trade["limit_price"] / trade["entry_price"]) - 1
                    num_hit += 1
                    trade["exited"] = True

    # Convert the filtered rows into a DataFrame for results
    res_df = pd.DataFrame(filtered_rows)

    # Print the final summary
    print(f"Net Profit in Units: {total_payout}")
    print(f"Total Trades: {num_hit}/{num_hit + num_miss}")
    print(f"Winning Trades: {num_hit}")
    print(f"Losing Trades: {num_miss}")
    return total_payout, num_hit, num_hit + num_miss, res_df

# %%
df = pd.read_csv("kalshi-historical-3-30-25-with-y.csv")
df['time'] = pd.to_datetime(df['time'])
cutoff_date = "2025-03-23"
df = df[df["time"] > cutoff_date]
_, _, _, res_df = calculate_total_payout_limits_and_price_history(df)
res_df
# Out:
# ('Yes', 87250, datetime.date(2025, 3, 26)) {'entry_time': Timestamp('2025-03-26
datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 00:00:04'), 'entry_price': 85, 'limit_price': 95.02, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': 85}
# ('Yes', 85250, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 09:26:04'), 'entry_price': 52, 'limit_price': 63.18, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(43.197159549327274)}
# ('Yes', 85250, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 09:42:04'), 'entry_price': 52, 'limit_price': 65.03999999999999, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(43.83360544671028)}
# ('Yes', 85250, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 09:46:04'), 'entry_price': 50, 'limit_price': 60.45, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(41.72957074874587)}
# ('Yes', 84750, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 00:46:04'), 'entry_price': 81, 'limit_price': 91.52, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(71.9551119409912)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 22:26:04'), 'entry_price': 60, 'limit_price': 74.31, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(42.39176329100498)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 22:28:05'), 'entry_price': 60, 'limit_price': 70.95, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(43.55737247274634)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 22:56:04'), 'entry_price': 51, 'limit_price': 71.33, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(31.052819748144852)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:22:04'), 'entry_price': 52, 'limit_price': 71.27, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(47.5)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:36:06'), 'entry_price': 61, 'limit_price': 72.18, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(49.06015075472056)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:42:05'), 'entry_price': 63, 'limit_price': 73.86, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(46.689267337118174)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:44:04'), 'entry_price': 63, 'limit_price': 75.39, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(44.69262443712917)}
# ('Yes', 84000, datetime.date(2025, 3, 28)) {'entry_time': Timestamp('2025-03-28 23:50:06'), 'entry_price': 65, 'limit_price': 76.89, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(45.2455068402148)}
# ('Yes', 83500, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 02:56:06'), 'entry_price': 66, 'limit_price': 76.33, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(49.98719262590098)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 19:56:04'), 'entry_price': 62, 'limit_price': 81.12, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.971083615727935)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 19:58:05'), 'entry_price': 61, 'limit_price': 82.78, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(55.9)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:00:04'), 'entry_price': 61, 'limit_price': 82.01, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.11635382117009)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:02:04'), 'entry_price': 61, 'limit_price': 82.63, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.66295031155971)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:36:04'), 'entry_price': 60, 'limit_price': 79.1, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.193426737865146)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:40:04'), 'entry_price': 59, 'limit_price': 80.0, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(55.387521626362314)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:42:04'), 'entry_price': 60, 'limit_price': 79.97, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.7)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:44:05'), 'entry_price': 60, 'limit_price': 79.1, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(57.16980566038302)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:50:04'), 'entry_price': 64, 'limit_price': 88.08, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(58.6)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:52:04'), 'entry_price': 65, 'limit_price': 88.19, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(58.365996683751206)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:54:04'), 'entry_price': 65, 'limit_price': 89.53, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(57.89436843060379)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:56:05'), 'entry_price': 64, 'limit_price': 89.36, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(56.84388373487406)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 20:58:04'), 'entry_price': 64, 'limit_price': 82.53999999999999, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(57.4)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:00:04'), 'entry_price': 64, 'limit_price': 82.03, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(58.39553749231918)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:02:04'), 'entry_price': 65, 'limit_price': 82.62, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(60.12557695721843)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:04:04'), 'entry_price': 67, 'limit_price': 89.26, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(62.746765936372654)}
# ('Yes', 82250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:06:05'), 'entry_price': 67, 'limit_price': 89.72, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(63.59265499251983)}
# ...
# ('Yes', 82750, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:44:06'), 'entry_price': 57, 'limit_price': 75.86, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(53.7)}
# ('Yes', 82750, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:46:05'), 'entry_price': 56, 'limit_price': 79.39, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(52.158125457540294)}
# ('Yes', 82750, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:48:05'), 'entry_price': 56, 'limit_price': 76.78, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(51.51001113587127)}
# ('Yes', 82750, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 21:50:05'), 'entry_price': 55, 'limit_price': 75.3, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64
}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:16:04'), 'entry_price': 51, 'limit_price': 72.0, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(44.05449785832587)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:18:04'), 'entry_price': 51, 'limit_price': 71.7, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(44.7)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:20:04'), 'entry_price': 52, 'limit_price': 72.35, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(46.62505813984932)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:22:06'), 'entry_price': 52, 'limit_price': 72.71000000000001, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(47.59091846299028)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:36:06'), 'entry_price': 51, 'limit_price': 72.98, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(46.746765936372654)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:42:04'), 'entry_price': 53, 'limit_price': 76.01, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(47.769321267751195)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 22:46:05'), 'entry_price': 53, 'limit_price': 80.4, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(47.03007537736028)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:40:04'), 'entry_price': 50, 'limit_price': 76.55, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(44.3)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:42:06'), 'entry_price': 51, 'limit_price': 76.77, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(45.3)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:44:05'), 'entry_price': 52, 'limit_price': 77.24, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(46.62505813984932)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:46:05'), 'entry_price': 51, 'limit_price': 78.75, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(46.01602568224916)}
# ('Yes', 83250, datetime.date(2025, 3, 29)) {'entry_time': Timestamp('2025-03-29 23:48:06'), 'entry_price': 52, 'limit_price': 77.51, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(47.5)}
# ('Yes', 82750, datetime.date(2025, 3, 30)) {'entry_time': Timestamp('2025-03-30 14:28:07'), 'entry_price': 50, 'limit_price': 60.21, 'exited': True, 'exit_time': None, 'exit_price': None, 'outcome': 'No', 'trailing_stop': np.float64(41.95015528100076)}
# Net Profit in Units: -125.0923267721963
# Total Trades: 1570/4608
# Winning Trades: 1570
# Losing Trades: 3038
#                       time currency event_type contract_type  strike_price  \
# 77825  2025-03-24 13:18:04      BTC      Daily           Yes         88250
# 77833  2025-03-24 13:20:05      BTC      Daily           Yes         88250
# 77925  2025-03-24 13:44:05      BTC      Daily           Yes         88250
# 77931  2025-03-24 13:46:05      BTC      Daily           Yes         88250
# 78061  2025-03-24 14:24:05      BTC      Daily           Yes         88250
# ...                    ...      ...        ...           ...           ...
# 116559 2025-03-30 13:02:04      BTC      Daily           Yes         82250
# 116569 2025-03-30 13:04:04      BTC      Daily           Yes         82250
# 116619 2025-03-30 13:14:05      BTC      Daily           Yes         82250
# 116757 2025-03-30 13:46:04      BTC      Daily           Yes         82250
# 116929 2025-03-30 14:28:07      BTC      Daily           Yes         82750
#
#         pdf_estimate  current_kalshi_price outcome
# 77825          61.31                    50      No
# 77833          61.00                    51      No
# 77925          64.77                    54      No
# 77931          62.42                    50      No
# 78061          64.16                    51      No
# ...              ...                   ...     ...
# 116559         65.77                    53     Yes
# 116569         65.37                    53     Yes
# 116619         66.44                    56     Yes
# 116757         67.01                    55     Yes
# 116929         60.21                    50      No
#
# [4608 rows x 8 columns]

# %%
daily_counts = res_df.groupby(res_df["time"].dt.date).size()
daily_counts
# Out:
# time
# 2025-03-24     953
# 2025-03-25     542
# 2025-03-26     537
# 2025-03-27    1275
# 2025-03-28     160
# 2025-03-29    1026
# 2025-03-30     115
# dtype: int64

# %%
# dates_to_drop = ['2025-02-04', '2025-02-05']

# # Filter out rows with the specified dates
# df = df[~df['time'].dt.date.isin(pd.to_datetime(dates_to_drop).date)]

# %%
# df.to_csv('kalshi-historical-2-4-25-with-y-REMOVED-STALE_DAYS.csv', index=False)
